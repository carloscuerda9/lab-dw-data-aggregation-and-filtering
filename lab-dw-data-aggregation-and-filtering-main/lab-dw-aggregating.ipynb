# %% [markdown]
# # Lab | Data Aggregation and Filtering

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company. We will use the dataset called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by first performing data cleaning, formatting, and structuring.

# %% [markdown]
# 1. Create a new DataFrame that only includes customers who have a total_claim_amount greater than $1,000 and have a response of "Yes" to the last marketing campaign.

# %% [markdown]
# 2. Using the original Dataframe, analyze the average total_claim_amount by each policy type and gender for customers who have responded "Yes" to the last marketing campaign. Write your conclusions.

# %% [markdown]
# 3. Analyze the total number of customers who have policies in each state, and then filter the results to only include states where there are more than 500 customers.

# %% [markdown]
# 4. Find the maximum, minimum, and median customer lifetime value by education level and gender. Write your conclusions.

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv"
df = pd.read_csv(url)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     10910 non-null  int64
#  1   Customer                       10910 non-null  object
#  2   State                          10279 non-null  object
#  3   Customer Lifetime Value        10910 non-null  float64
#  4   Response                       10279 non-null  object
#  5   Coverage                       10910 non-null  object
#  6   Education                      10910 non-null  object
#  7   Effective To Date              10910 non-null  object
#  8   EmploymentStatus               10910 non-null  object
#  9   Gender                         10910 non-null  object
#  10  Income                         10910 non-null  int64
#  11  Location Code                  10910 non-null  object
#  12  Marital Status                 10910 non-null  object
#  13  Monthly Premium Auto           10910 non-null  int64
#  14  Months Since Last Claim        10277 non-null  float64
#  15  Months Since Policy Inception  10910 non-null  int64
#  16  Number of Open Complaints      10277 non-null  float64
#  17  Number of Policies             10910 non-null  int64
#  18  Policy Type                    10910 non-null  object
#  19  Policy                         10910 non-null  object
#  20  Renew Offer Type               10910 non-null  object
#  21  Sales Channel                  10910 non-null  object
#  22  Total Claim Amount             10910 non-null  float64
#  23  Vehicle Class                  10288 non-null  object
#  24  Vehicle Size                   10288 non-null  object
#  25  Vehicle Type                   5428 non-null   object
# dtypes: float64(4), int64(5), object(17)
# memory usage: 2.2+ MB

# %%
df.sample(25)
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 5283         5283  GJ59592  California              5318.896640      Yes
# 260           260  MS11057      Oregon              9587.586583       No
# 303           303  DN98431      Oregon              2535.321683       No
# 8367         8367  AJ89108  California             11009.130490      Yes
# 8146         8146  XM96138  California             11277.724880       No
# 4766         4766  SE47384  California              5526.438887       No
# 9120         9120  QK31192     Arizona              4079.132667       No
# 7716         7716  MB32944      Nevada              2635.505781       No
# 4758         4758  XR97812  California              2345.084479       No
# 6438         6438  TP41703         NaN              7250.029606      NaN
# 5562         5562  GY55415      Nevada             15725.250530       No
# 8993         8993  JC16991     Arizona              7423.899674       No
# 9623         9623  CX58204      Nevada              8079.833042       No
# 9192         9192  AE60813      Oregon              4993.025273       No
# 7779         7779  DO83789     Arizona              5206.028448       No
# 991           991  MU57098      Oregon              5678.050167      Yes
# 2275         2275  TJ90326  California             13530.029060       No
# 5237         5237  EC94366      Oregon              3776.320768       No
# 3272         3272  VM34210  Washington              7399.032079       No
# 3238         3238  BI76326  California             12275.343090       No
# 3573         3573  VB26229     Arizona              8697.882675       No
# 425           425  DL53457  California              4605.036646      Yes
# 10327       10327  ZE59592      Oregon              5470.181751       No
# 9366         9366  VY90611  California              2499.036551       No
# 756           756  VX85673     Arizona              4250.282624      Yes
#
#        Coverage             Education Effective To Date EmploymentStatus  \
# 5283      Basic              Bachelor           1/12/11         Employed
# 260     Premium              Bachelor           1/31/11         Employed
# 303       Basic  High School or Below           2/27/11       Unemployed
# 8367    Premium              Bachelor           1/24/11         Employed
# 8146   Extended                Master            2/1/11         Employed
# 4766   Extended              Bachelor            2/6/11         Employed
# 9120    Premium  High School or Below           2/18/11       Unemployed
# 7716      Basic                Master            1/6/11         Employed
# 4758      Basic               College           2/22/11       Unemployed
# 6438      Basic              Bachelor            2/1/11       Unemployed
# 5562    Premium              Bachelor           2/27/11       Unemployed
# 8993      Basic                Master           2/12/11         Employed
# 9623      Basic  High School or Below            2/2/11         Disabled
# 9192      Basic               College           2/17/11         Employed
# 7779      Basic               College            2/2/11         Employed
# 991    Extended              Bachelor           1/19/11       Unemployed
# 2275   Extended                Doctor            2/2/11         Employed
# 5237   Extended                Doctor           2/12/11    Medical Leave
# 3272      Basic               College            1/1/11       Unemployed
# 3238    Premium               College            1/8/11         Employed
# 3573      Basic              Bachelor           1/31/11         Employed
# 425       Basic               College           1/28/11    Medical Leave
# 10327     Basic               College            1/6/11         Employed
# 9366      Basic                Master           1/27/11         Employed
# 756       Basic  High School or Below           1/18/11       Unemployed
#
#       Gender  ...  Number of Open Complaints Number of Policies  \
# 5283       F  ...                        0.0                  6
# 260        M  ...                        0.0                  4
# 303        F  ...                        0.0                  1
# 8367       F  ...                        0.0                  1
# 8146       M  ...                        1.0                  2
# 4766       F  ...                        0.0                  1
# 9120       M  ...                        0.0                  1
# 7716       M  ...                        0.0                  1
# 4758       M  ...                        0.0                  1
# 6438       M  ...                        0.0                  2
# 5562       F  ...                        0.0                  2
# 8993       F  ...                        0.0                  2
# 9623       F  ...                        0.0                  6
# 9192       F  ...                        1.0                  7
# 7779       F  ...                        0.0                  4
# 991        F  ...                        0.0                  3
# 2275       F  ...                        2.0                  2
# 5237       M  ...                        0.0                  1
# 3272       F  ...                        0.0                  6
# 3238       F  ...                        NaN                  9
# 3573       M  ...                        0.0                  2
# 425        F  ...                        0.0                  9
# 10327      M  ...                        0.0                  3
# 9366       F  ...                        0.0                  1
# 756        F  ...                        1.0                  7
#
#           Policy Type        Policy  Renew Offer Type  Sales Channel  \
# 5283   Corporate Auto  Corporate L2            Offer2    Call Center
# 260     Personal Auto   Personal L3            Offer1    Call Center
# 303    Corporate Auto  Corporate L3            Offer1         Branch
# 8367    Personal Auto   Personal L3            Offer2          Agent
# 8146    Personal Auto   Personal L1            Offer3          Agent
# 4766     Special Auto    Special L3            Offer3          Agent
# 9120   Corporate Auto  Corporate L2            Offer4         Branch
# 7716    Personal Auto   Personal L1            Offer4         Branch
# 4758    Personal Auto   Personal L3            Offer1          Agent
# 6438    Personal Auto   Personal L3            Offer4    Call Center
# 5562   Corporate Auto  Corporate L1            Offer1            Web
# 8993    Personal Auto   Personal L2            Offer1    Call Center
# 9623    Personal Auto   Personal L1            Offer1          Agent
# 9192    Personal Auto   Personal L3            Offer4         Branch
# 7779    Personal Auto   Personal L3            Offer4         Branch
# 991     Personal Auto   Personal L1            Offer2          Agent
# 2275    Personal Auto   Personal L3            Offer2    Call Center
# 5237   Corporate Auto  Corporate L2            Offer2          Agent
# 3272    Personal Auto   Personal L2            Offer1            Web
# 3238    Personal Auto   Personal L3            Offer2    Call Center
# 3573    Personal Auto   Personal L3            Offer2         Branch
# 425     Personal Auto   Personal L3            Offer2            Web
# 10327   Personal Auto   Personal L1            Offer3          Agent
# 9366   Corporate Auto  Corporate L3            Offer2          Agent
# 756     Personal Auto   Personal L3            Offer1          Agent
#
#        Total Claim Amount  Vehicle Class Vehicle Size Vehicle Type
# 5283           321.600000  Four-Door Car        Small          NaN
# 260             65.428481  Four-Door Car      Medsize          NaN
# 303            326.400000  Four-Door Car      Medsize            A
# 8367          1358.400000     Luxury Car      Medsize            A
# 8146           427.527310  Four-Door Car      Medsize            A
# 4766           657.600000            SUV      Medsize            A
# 9120           631.124372   Two-Door Car      Medsize            A
# 7716           316.800000            NaN          NaN          NaN
# 4758           331.200000  Four-Door Car      Medsize          NaN
# 6438           496.800000   Two-Door Car      Medsize          NaN
# 5562          1072.800000            SUV      Medsize          NaN
# 8993           297.600000  Four-Door Car        Small          NaN
# 9623           734.400000            SUV      Medsize          NaN
# 9192           101.341650  Four-Door Car      Medsize          NaN
# 7779           312.000000  Four-Door Car        Small          NaN
# 991            364.800000  Four-Door Car        Small            A
# 2275           180.555113  Four-Door Car        Small          NaN
# 5237           291.536748  Four-Door Car      Medsize          NaN
# 3272           337.617149            SUV      Medsize          NaN
# 3238           430.505942            SUV        Small          NaN
# 3573           350.400000  Four-Door Car      Medsize          NaN
# 425            302.400000  Four-Door Car        Large          NaN
# 10327          746.107437   Two-Door Car      Medsize            A
# 9366           364.622773   Two-Door Car        Small            A
# 756            292.800000            NaN          NaN          NaN
#
# [25 rows x 26 columns]

# %%
df = df.drop_duplicates()
df = df.dropna()

df
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 10             10  HG93801     Arizona              5154.764074       No
# 13             13  KR82385  California              5454.587929       No
# 16             16  FH51383  California              5326.677654       No
# ...           ...      ...         ...                      ...      ...
# 10902       10902  PP30874  California              3579.023825       No
# 10903       10903  SU71163     Arizona              2771.663013       No
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10908       10908  WA60547  California             11971.977650       No
#
#        Coverage             Education Effective To Date EmploymentStatus  \
# 2         Basic              Bachelor           2/10/11         Employed
# 3      Extended               College           1/11/11         Employed
# 10     Extended  High School or Below            1/2/11         Employed
# 13        Basic                Master           1/26/11         Employed
# 16        Basic  High School or Below            2/7/11         Employed
# ...         ...                   ...               ...              ...
# 10902  Extended  High School or Below           1/24/11         Employed
# 10903     Basic               College            1/7/11         Employed
# 10904     Basic  High School or Below           2/24/11       Unemployed
# 10906     Basic               College            1/6/11         Employed
# 10908   Premium               College           2/13/11         Employed
#
#       Gender  ...  Number of Open Complaints Number of Policies  \
# 2          M  ...                        0.0                  2
# 3          M  ...                        0.0                  2
# 10         M  ...                        0.0                  1
# 13         M  ...                        0.0                  4
# 16         F  ...                        0.0                  6
# ...      ...  ...                        ...                ...
# 10902      F  ...                        2.0                  1
# 10903      M  ...                        4.0                  1
# 10904      M  ...                        0.0                  2
# 10906      F  ...                        0.0                  6
# 10908      F  ...                        4.0                  6
#
#           Policy Type        Policy  Renew Offer Type  Sales Channel  \
# 2       Personal Auto   Personal L3            Offer3    Call Center
# 3      Corporate Auto  Corporate L3            Offer2         Branch
# 10     Corporate Auto  Corporate L3            Offer2         Branch
# 13      Personal Auto   Personal L3            Offer4    Call Center
# 16      Personal Auto   Personal L3            Offer4    Call Center
# ...               ...           ...               ...            ...
# 10902   Personal Auto   Personal L2            Offer2          Agent
# 10903   Personal Auto   Personal L2            Offer2         Branch
# 10904   Personal Auto   Personal L2            Offer1         Branch
# 10906   Personal Auto   Personal L3            Offer2         Branch
# 10908   Personal Auto   Personal L1            Offer1         Branch
#
#        Total Claim Amount  Vehicle Class Vehicle Size Vehicle Type
# 2              480.000000            SUV      Medsize            A
# 3              484.013411  Four-Door Car      Medsize            A
# 10             442.521087            SUV        Large            A
# 13             331.200000   Two-Door Car      Medsize            A
# 16             300.528579   Two-Door Car        Large            A
# ...                   ...            ...          ...          ...
# 10902          655.200000  Four-Door Car      Medsize            A
# 10903          355.200000   Two-Door Car      Medsize            A
# 10904          897.600000     Luxury SUV      Medsize            A
# 10906          273.018929  Four-Door Car      Medsize            A
# 10908          618.288849            SUV      Medsize            A
#
# [4543 rows x 26 columns]

# %%
pd.set_option('display.max_columns', None)
df_mayor1000 = df[(df['Total Claim Amount'] > 1000) & (df['Response'] == 'Yes')]
df_mayor1000
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 236           236  YJ16163      Oregon             11009.130490      Yes
# 419           419  GW43195      Oregon             25807.063000      Yes
# 442           442  IP94270     Arizona             13736.132500      Yes
# 587           587  FJ28407  California              5619.689084      Yes
# 1527         1527  TU53781      Oregon              8427.172486      Yes
# 1809         1809  QO62792      Oregon              7840.165778      Yes
# 2027         2027  TA66375      Oregon             11009.130490      Yes
# 2125         2125  JC11405      Oregon             10963.957230      Yes
# 2865         2865  FH77504  California             11009.130490      Yes
# 3958         3958  KC26486     Arizona              8427.172486      Yes
# 4475         4475  WP58340     Arizona             10963.957230      Yes
# 4521         4521  LT72149      Nevada              5619.689084      Yes
# 4566         4566  TC99043  California             13736.132500      Yes
# 5013         5013  GP83239  California              7840.165778      Yes
# 5331         5331  UT48216      Nevada              7840.165778      Yes
# 5489         5489  TQ84956  California             10963.957230      Yes
# 5896         5896  TY31217  Washington             11009.130490      Yes
# 7255         7255  PN98247  California              7840.165778      Yes
# 8340         8340  MJ51323      Oregon              8427.172486      Yes
# 8367         8367  AJ89108  California             11009.130490      Yes
# 8505         8505  DT77901      Oregon             10179.717040      Yes
# 8662         8662  YU86361  Washington             19160.989940      Yes
# 8835         8835  XT93203  California             10963.957230      Yes
# 9498         9498  IV54766      Oregon             19160.989940      Yes
# 9581         9581  GD55093  California             19160.989940      Yes
# 10009       10009  YP53257      Oregon             10179.717040      Yes
# 10708       10708  CK39096      Oregon              5619.689084      Yes
#
#        Coverage             Education Effective To Date EmploymentStatus  \
# 236     Premium              Bachelor           1/24/11         Employed
# 419    Extended               College           2/13/11         Employed
# 442     Premium                Master           2/13/11         Disabled
# 587     Premium  High School or Below           1/26/11       Unemployed
# 1527   Extended              Bachelor           2/10/11         Employed
# 1809   Extended               College           1/14/11         Employed
# 2027    Premium              Bachelor           1/24/11         Employed
# 2125    Premium  High School or Below            2/8/11         Employed
# 2865    Premium              Bachelor           1/24/11         Employed
# 3958   Extended              Bachelor           2/10/11         Employed
# 4475    Premium  High School or Below            2/8/11         Employed
# 4521    Premium  High School or Below           1/26/11       Unemployed
# 4566    Premium                Master           2/13/11         Disabled
# 5013   Extended               College           1/14/11         Employed
# 5331   Extended               College           1/14/11         Employed
# 5489    Premium  High School or Below            2/8/11         Employed
# 5896    Premium              Bachelor           1/24/11         Employed
# 7255   Extended               College           1/14/11         Employed
# 8340   Extended              Bachelor           2/10/11         Employed
# 8367    Premium              Bachelor           1/24/11         Employed
# 8505    Premium              Bachelor            1/5/11          Retired
# 8662   Extended                Master           2/20/11         Employed
# 8835    Premium  High School or Below            2/8/11         Employed
# 9498   Extended                Master           2/20/11         Employed
# 9581   Extended                Master           2/20/11         Employed
# 10009   Premium              Bachelor            1/5/11          Retired
# 10708   Premium  High School or Below           1/26/11       Unemployed
#
#       Gender  Income Location Code Marital Status  Monthly Premium Auto  \
# 236        F   51643      Suburban         Single                   283
# 419        F   71210      Suburban        Married                   214
# 442        F   16181      Suburban       Divorced                   181
# 587        M       0      Suburban        Married                   153
# 1527       F   46503      Suburban       Divorced                   215
# 1809       M   58414      Suburban         Single                   210
# 2027       F   51643      Suburban         Single                   283
# 2125       M   55687      Suburban       Divorced                   276
# 2865       F   51643      Suburban         Single                   283
# 3958       F   46503      Suburban       Divorced                   215
# 4475       M   55687      Suburban       Divorced                   276
# 4521       M       0      Suburban        Married                   153
# 4566       F   16181      Suburban       Divorced                   181
# 5013       M   58414      Suburban         Single                   210
# 5331       M   58414      Suburban         Single                   210
# 5489       M   55687      Suburban       Divorced                   276
# 5896       F   51643      Suburban         Single                   283
# 7255       M   58414      Suburban         Single                   210
# 8340       F   46503      Suburban       Divorced                   215
# 8367       F   51643      Suburban         Single                   283
# 8505       F   14290      Suburban        Married                   271
# 8662       F   22705      Suburban       Divorced                   239
# 8835       M   55687      Suburban       Divorced                   276
# 9498       F   22705      Suburban       Divorced                   239
# 9581       F   22705      Suburban       Divorced                   239
# 10009      F   14290      Suburban        Married                   271
# 10708      M       0      Suburban        Married                   153
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 236                       16.0                             43
# 419                        8.0                             89
# 442                       22.0                             79
# 587                       25.0                              5
# 1527                       4.0                             21
# 1809                       7.0                             24
# 2027                      16.0                             43
# 2125                      33.0                             91
# 2865                      16.0                             43
# 3958                       4.0                             21
# 4475                      33.0                             91
# 4521                      25.0                              5
# 4566                      22.0                             79
# 5013                       7.0                             24
# 5331                       7.0                             24
# 5489                      33.0                             91
# 5896                      16.0                             43
# 7255                       7.0                             24
# 8340                       4.0                             21
# 8367                      16.0                             43
# 8505                      20.0                             40
# 8662                      19.0                             59
# 8835                      33.0                             91
# 9498                      19.0                             59
# 9581                      19.0                             59
# 10009                     20.0                             40
# 10708                     25.0                              5
#
#        Number of Open Complaints  Number of Policies     Policy Type  \
# 236                          0.0                   1    Special Auto
# 419                          1.0                   2   Personal Auto
# 442                          0.0                   8   Personal Auto
# 587                          0.0                   1   Personal Auto
# 1527                         1.0                   1  Corporate Auto
# 1809                         2.0                   1   Personal Auto
# 2027                         0.0                   1  Corporate Auto
# 2125                         0.0                   1   Personal Auto
# 2865                         0.0                   1   Personal Auto
# 3958                         1.0                   1   Personal Auto
# 4475                         0.0                   1   Personal Auto
# 4521                         0.0                   1   Personal Auto
# 4566                         0.0                   8   Personal Auto
# 5013                         2.0                   1   Personal Auto
# 5331                         2.0                   1   Personal Auto
# 5489                         0.0                   1  Corporate Auto
# 5896                         0.0                   1   Personal Auto
# 7255                         2.0                   1   Personal Auto
# 8340                         1.0                   1   Personal Auto
# 8367                         0.0                   1   Personal Auto
# 8505                         0.0                   1   Personal Auto
# 8662                         0.0                   7   Personal Auto
# 8835                         0.0                   1   Personal Auto
# 9498                         0.0                   7   Personal Auto
# 9581                         0.0                   7   Personal Auto
# 10009                        0.0                   1   Personal Auto
# 10708                        0.0                   1   Personal Auto
#
#              Policy Renew Offer Type Sales Channel  Total Claim Amount  \
# 236      Special L3           Offer2         Agent         1358.400000
# 419     Personal L2           Offer1        Branch         1027.200000
# 442     Personal L2           Offer1           Web         1261.319869
# 587     Personal L1           Offer2           Web         1027.000029
# 1527   Corporate L3           Offer1         Agent         1032.000000
# 1809    Personal L3           Offer2         Agent         1008.000000
# 2027   Corporate L2           Offer2         Agent         1358.400000
# 2125    Personal L3           Offer1         Agent         1324.800000
# 2865    Personal L3           Offer2         Agent         1358.400000
# 3958    Personal L2           Offer1         Agent         1032.000000
# 4475    Personal L2           Offer1         Agent         1324.800000
# 4521    Personal L2           Offer2           Web         1027.000029
# 4566    Personal L2           Offer1           Web         1261.319869
# 5013    Personal L3           Offer2         Agent         1008.000000
# 5331    Personal L1           Offer2         Agent         1008.000000
# 5489   Corporate L3           Offer1         Agent         1324.800000
# 5896    Personal L3           Offer2         Agent         1358.400000
# 7255    Personal L3           Offer2         Agent         1008.000000
# 8340    Personal L2           Offer1         Agent         1032.000000
# 8367    Personal L3           Offer2         Agent         1358.400000
# 8505    Personal L3           Offer1         Agent         1300.800000
# 8662    Personal L1           Offer2         Agent         1294.700423
# 8835    Personal L3           Offer1         Agent         1324.800000
# 9498    Personal L1           Offer2         Agent         1294.700423
# 9581    Personal L1           Offer2         Agent         1294.700423
# 10009   Personal L3           Offer1         Agent         1300.800000
# 10708   Personal L3           Offer2           Web         1027.000029
#
#       Vehicle Class Vehicle Size Vehicle Type
# 236      Luxury Car      Medsize            A
# 419      Luxury Car        Small            A
# 442             SUV      Medsize            A
# 587             SUV      Medsize            A
# 1527     Luxury SUV      Medsize            A
# 1809     Luxury SUV        Small            A
# 2027     Luxury Car      Medsize            A
# 2125     Luxury SUV      Medsize            A
# 2865     Luxury Car      Medsize            A
# 3958     Luxury SUV      Medsize            A
# 4475     Luxury SUV      Medsize            A
# 4521            SUV      Medsize            A
# 4566            SUV      Medsize            A
# 5013     Luxury SUV        Small            A
# 5331     Luxury SUV        Small            A
# 5489     Luxury SUV      Medsize            A
# 5896     Luxury Car      Medsize            A
# 7255     Luxury SUV        Small            A
# 8340     Luxury SUV      Medsize            A
# 8367     Luxury Car      Medsize            A
# 8505     Luxury SUV      Medsize            A
# 8662     Luxury SUV      Medsize            A
# 8835     Luxury SUV      Medsize            A
# 9498     Luxury SUV      Medsize            A
# 9581     Luxury SUV      Medsize            A
# 10009    Luxury SUV      Medsize            A
# 10708           SUV      Medsize            A

# %%
df_yes = df[df["Response"] == "Yes"]
pivot_table = pd.pivot_table(df_yes, values='Total Claim Amount', index=['Policy Type', 'Gender'], aggfunc='mean')
pivot_table
# Out:
#                        Total Claim Amount
# Policy Type    Gender
# Corporate Auto F               404.104008
#                M               391.370774
# Personal Auto  F               457.056315
#                M               472.489180
# Special Auto   F               495.689401
#                M               368.523035

# %%
state_customer_counts = df['State'].value_counts()
states_mas_500 = state_customer_counts[state_customer_counts > 500]
states_mas_500
# Out:
# State
# California    1552
# Oregon        1281
# Arizona        868
# Name: count, dtype: int64

# %%
indice_stats = df.groupby(['Education', 'Gender'])['Customer Lifetime Value'].agg(['max', 'min', 'median'])
indice_stats
# Out:
#                                      max          min       median
# Education            Gender
# Bachelor             F       58753.88046  1904.000852  5752.485185
#                      M       67907.27050  2030.783687  5797.377350
# College              F       61850.18803  2004.350666  5642.596077
#                      M       44795.46942  1918.119700  6005.847375
# Doctor               F       44856.11397  2395.570000  5789.850900
#                      M       32677.34284  2267.604038  5843.989737
# High School or Below F       55277.44589  2150.178588  5978.754765
#                      M       83325.38119  2132.771675  6081.481291
# Master               F       51016.06704  2417.777032  5714.165863
#                      M       50568.25912  2357.503128  5512.342258

# %% [markdown]
# ## Bonus

# %% [markdown]
# 5. The marketing team wants to analyze the number of policies sold by state and month. Present the data in a table where the months are arranged as columns and the states are arranged as rows.

# %% [markdown]
# 6.  Display a new DataFrame that contains the number of policies sold by month, by state, for the top 3 states with the highest number of policies sold.
#
# *Hint:*
# - *To accomplish this, you will first need to group the data by state and month, then count the number of policies sold for each group. Afterwards, you will need to sort the data by the count of policies sold in descending order.*
# - *Next, you will select the top 3 states with the highest number of policies sold.*
# - *Finally, you will create a new DataFrame that contains the number of policies sold by month for each of the top 3 states.*

# %% [markdown]
# 7. The marketing team wants to analyze the effect of different marketing channels on the customer response rate.
#
# Hint: You can use melt to unpivot the data and create a table that shows the customer response rate (those who responded "Yes") by marketing channel.

# %% [markdown]
# External Resources for Data Filtering: https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9

# %%
# your code goes here
